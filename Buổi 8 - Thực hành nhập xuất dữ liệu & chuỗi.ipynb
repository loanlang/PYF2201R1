# %% [markdown]
# # Thực hành nhập xuất dữ liệu & chuỗi
#
# ### Bài tập tra cứu lệnh
#
# Nhập vào một chuỗi, kiểm tra xem chuỗi đó có ký tự nào là chữ in hoa hay không, nếu có thì in True, không có thì in False

# %%
chuoi = input("Nhập vào một chuỗi:")

check = False

a = 0

for i in range(len(chuoi)):
    kt = chuoi[a].isupper()
    check = kt or check
    print(a,chuoi[a],check)
    a += 1
    
print(check)

# %%
chuoi = input("Nhập vào một chuỗi:")

a = 0

for i in range(len(chuoi)):
    print(a,chuoi[a])
    a += 1
print check
# Out:
#   File "C:\Users\Phung\AppData\Local\Temp/ipykernel_16992/3574215799.py", line 8
#     print check
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
chuoi = input("Nhập vào một chuỗi:")
print(not chuoi.islower())

# %%
a=input()
l= len(a)
check=False
for i in range(l):
    kt=a[i].isupper()
    check=kt or check
print(check)

# %%
c = input()
n = len(c)
stt = 0
s = 0
for i in range(n):
    a = int(c[stt].isupper())  
    u += 1
    s += a
print(s >= 1)

# %%
a = input("nhap chuoi")
x=a.islower()
print(not x)

# %%
a=input()
l= len(a)
check=False
for i in range(l):
    kt=a[i].isupper()
    check=kt or check
print(check)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Nhập vào một chuỗi, kiểm tra xem chuỗi đó có ký tự nào là chữ in thường hay không, nếu có thì in True, không có thì in False

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#kiểm tra xem chuỗi đó có ký tự nào là chữ in hoa hay không, nếu có thì in True, không có thì in Fals
a = input("Enter sth: ")
print(not a.islower())

# %% [markdown]
# Nhập vào một chuỗi a và chuỗi b, tìm vị trí đầu tiên xuất hiện chuỗi b trong chuỗi a

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
chuoi = input("Nhập vào một chuỗi:")
print(not chuoi.isupper())

# %%
a = input("Nhập vào một chuỗi a:")
b = input("Nhập vào một chuỗi b:")
print(a.find(b)) # tim tu ben trai
print(a.rfind(b)) # tim tu ben phai

# %% [markdown]
# Nhập vào một chuỗi a, hãy xóa từ đầu tiên trong chuỗi a, rồi in ra màn hình

# %%
c = input()
print(c[1:])

# %%
a = input()
b = a+" "
print(b.count("n "))

# %%
a = input("Nhập vào một chuỗi a:")
b = a.find(" ")
a = a[b+1:]
print(a)

# %% [markdown]
# ### Bài 1
#
# Nhập vào một chuỗi, đếm xem có bao nhiêu từ trong chuỗi kết thúc bằng chữ n

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a= input()
b=a+" "
print(b.count("n "))

# %%
a = input("Nhập vào một chuỗi a: ")
a += " "
b = a.count("n ")
print(b)

# %% [markdown]
# ### Bài 2
#
# Nhập vào một chuỗi, kiểm tra xem chuỗi đó có ký tự hoa hoặc ký tự thường hay không.

# %%
a = input("Nhập vào một chuỗi a: ")
print(a.isalpha())
print(not a.islower() or not a.isupper())
print(not a.islower() and a.isupper())

# %%
a = input("Nhập vào một chuỗi a: ")

print(not a.islower() or not a.isupper())
print(not a.islower() and a.isupper())

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = input()
l=len(a)
x2=False
x4=False
s1=0
s2=0
for i in range(l):
    x1=a[i].isupper()
    x2=x1 or x2
    s1=s1+int(x1)
    
    x3=a[i].islower()
    x4=x3 or x4
    s2=s2+int(x3)
    
print("Chuoi co ",s1," ky tu Hoa"," va co", s2," ky tu

# %% [markdown]
# ### Bài 3
#
# Nhập vào một chuỗi, kiểm tra tính đối xứng của chuỗi đó

# %%
a = input("Nhập vào một chuỗi a: ")
chuoidaonguoc = a[::-1]
print(chuoidaonguoc == a)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Bài 4
#
# Nhập vào một chuỗi, in ra những ký tự in hoa trong chuỗi đó

# %%
a = input("Nhập vào một chuỗi a: ")
stt = 0
for i in range(len(a)):
    print(a[stt],a[stt].isupper())
    stt += 1
# Out:
# Nhập vào một chuỗi a: chao ban
# c False
# h False
# a False
# o False
#   False
# b False
# a False
# n False

# %% [markdown]
# ### Bài 5
#
# Nhập vào một chuỗi, tìm các ký tự chỉ xuất hiện một lần trong chuỗi (nếu xuất hiện 1 lần in true, xuất hiện nhiều lần in false)
#
# Ví dụ:
#
# Nhập chuỗi: "ABAbc"
#
# In:
#
# A: False
#
# B: True
#
# A: False
#
# b: True
#
# c: True

# %%
a = input("Nhập vào một chuỗi a: ")
stt = 0
for i in range(len(a)):
    b = a[stt]
    print(b,":",a.count(b) == 1,sep = "")
    stt += 1

# %% [markdown]
# ### Bài 6
#
# Nhập vào một chuỗi, kiểm tra trong chuỗi có con số hay không, nếu có in True, không có in False

# %%
a = input("Nhập vào một chuỗi a: ")
stt = 0
kiemtra = False

for i in range(len(a)):
    b = a[stt]
    check = b.isnummeric()
    kiemtra = kiemtra or check
    stt += 1
    
print (kiemtra)

# %% [markdown]
# ### Bài 7
#
# Nhập vào một chuỗi, tách những con số có trong chuỗi ra rồi tính tổng của chúng
#
# In tổng lên màn hình

# %%
a = input("Nhập vào một chuỗi a: ")
so = 0
tong = 0

for i in range(10):
    b= a.count(str(so))
    tong += b*so
    so += 1
    
print(tong)

# %%
a=input()
l=len(a)
s=0
for i in range(l):
    x1= a[i].isnumeric()
    x2= int(x1) *a[i]
    s=s+x2
print(s)

# %%
import re
st="abc123"
s1=re.sub( r'\D',"", st)
for i in range(len(s1)):
        s+=int(s1[i])
print(s)

# %% [markdown]
# ### Bài 8
#
# Nhập vào một chuỗi, đảo ngược chuỗi đã nhập rồi in ra màn hình

# %%
a = input("Nhập vào một chuỗi a: ")
a = a[::-1]
print(a)
# Out:
# Nhập vào một chuỗi a: abcd
# dcba

# %%
chuoi = "hello hi"
chuoi2 = chuoi[::-1]
print(chuoi2)
# Out:
# ih olleh

# %% [markdown]
# ### Bài 9
#
# Nhập vào một chuỗi, kiểm tra xem mỗi từ trong chuỗi có được viết hoa chữ cái đầu hay không, nếu tất cả đều được viết hoa thì in ra True, còn không thì in ra False
#
# Trong trường hợp là False, hãy viết hoa tất cả các chữ cái đầu của mỗi từ rồi in lên màn hình
#
# Cách làm thông thường:

# %%
a = input("Nhập vào một chuỗi: ")
a0 = a
kiemtra = True
sokhoangtrang = a.coun(" ")

for i in range(sokhoangtrang +1):
    b = a.find(" ")
    check = a[b+1].isupper()
    kiemtra = kiemtra and check
    viethoa = a[b+1].upper()
    a0 = a0[:b+1] + viethoa + a0[b+2:]
    a =  a[:b] + "*" + a[b+1:]

print(kiemtra)
# a0 = a0[1:]
print(a0)

# %%
a = input("Nhập vào một chuỗi:")
a0 = a
kiemtra = True
sokhoangtrang = a.count(" ")

for i in range(sokhoangtrang + 1):
    b = a.find(" ")
    check = a[b+1].isupper()
    kiemtra = kiemtra and check
    viethoa = a[b+1].upper()
    a0 = a0[:b+1] + viethoa + a0[b+2:]
    a = a[:b] + "*" + a[b+1:]

print(kiemtra)
#print(a)
print(a0)

# %%
a = "xin chào"
a = a[:2] + "N" + a[2+1:]
print(a)

# %% [markdown]
# Cách sử dụng lệnh có sẵn:

# %%
st="Chuc Mung nam moi"
print(st.istitle())
print(st.title())
