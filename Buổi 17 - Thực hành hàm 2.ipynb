# %% [markdown]
# # Bài tập lớn
#
# ## Bài 1
#
# Viết chương trình như sau:
#
# Viết 3 hàm, cả 3 hàm đều có đầu vào là 1 chuỗi
#
# Hàm thứ nhất tách toàn bộ chữ cái ra thành 1 chuỗi riêng biệt và trả về chuỗi đó (chuỗi chỉ toàn chữ cái)
#
# Hàm thứ hai tách các con số trong chuỗi ra (các chữ số liền nhau là 1 con số), sau đó chèn các con số đó vào một chuỗi, mỗi số cách nhau một dấu phẩy. Trả về chuỗi đó (chuỗi đã tách số)
#
# Hàm thứ ba, tách các ký tự đặc biệt ra thành 1 chuỗi, mỗi 1 ký tự đặc biệt cách nhau một khoảng trắng. Trả về chuỗi đó (chuỗi đã tách)
#
# Ví dụ: Cho chuỗi a = "ABcde456asd@34!@avd^%"
#
# Chạy hàm 1 với đầu vào chuỗi a sẽ trả về chuỗi: "ABcdeasdavd"
#
# Chạy hàm 2 với đầu vào chuỗi a sẽ trả về chuỗi: "456,34"
#
# Chạy hàm 3 với đầu vào chuỗi a sẽ trả về chuỗi: "@ ! @ ^ %"
#
# Sau khi viết xong 3 hàm trên, viết chương trình chính như sau:
#
# <b>B1</b>: Yêu cầu người dùng nhập vào chuỗi
#
# <b>B2</b>: Yêu cầu người dùng chọn chạy hàm 1, hoặc hàm 2 hoặc hàm 3 bằng cách nhập vào 1 hoặc 2 hoặc 3 tương ứng
#
# <b>B3</b>: In ra màn hình giá trị chuỗi tưng ứng giá trị trả về của các hàm chạy trong B2
#
# <b>B4</b>: Thực hiện lại B2 cho đến khi nào người dùng nhập 0 thì ngưng chương trình

# %%
def ham1(a):
    a0 = ""
    for i in a:
        if i.isalpha():
            a0 += i
    return a0

def ham2(a):
    a0 = ""
    kq = ""
    a += ""
    for i in a :
        if i.isnumeric():
            a0 += i
        else:
            if a0 != "":
                kq += a0 + ","
                a0 = ""
    return kq[:-1]            

def ham3(a):
    kq = ""
    for i in a:
        if not i.isalnum():
            kq += i + ""
    return kq[:-1]    

a = "ABcde456asd@34!@avd^%"
ham = input("Mời nhập hàm muốn chạy:")
while ham != "0":
    if ham == "1":
        print(ham1(a))
    elif ham == "2":
        print(ham2(a))
    elif ham == "3":
        print(ham3(a))
    ham = input("Mời nhập hàm muốn chạy:")
# Out:
# Mời nhập hàm muốn chạy:1
# ABcdeasdavd
# Mời nhập hàm muốn chạy:2
# 456,34
# Mời nhập hàm muốn chạy:3
# @!@^

# %%
a = input("nhập chuỗi: ")

def ham1(a):
    a0 = ""
    for i in a:
        if i.isalpha():
            a0 += i
    return a0

def ham2(a):
    demso=str()
    a += "a"
    d=str()
    for i in a:
        if (not i.isnumeric()) and d.isnumeric():
            demso+=","
    
        if i.isnumeric():
            demso+=i
        d=i
    if demso[len(demso) - 1] == ",":
        demso = demso[:-1]
    return demso

def ham3(a):
    kq = ""
    for i in a:
        if not i.isalnum():
            kq += i + ""
    return kq[:-1]        

a = "ABcde456asd@34!@avd^%56"
ham = input("Mời nhập hàm muốn chạy:")
while ham != "0":
    if ham == "1":
        print(ham1(a))
    elif ham == "2":
        print(ham2(a))
    elif ham == "3":
        print(ham3(a))
    ham = input("Mời nhập hàm muốn chạy:")

# %%
a = "ABcde456asd@34!@avd^%"

def ham1(a):
    chuoi1 = ""
    for i in a:
        if i.isalpha():
            chuoi1 += i
    return chuoi1

#print(ham1(a))

def ham2(a):
    vitri1=0
    vitri2=0
    chuoikq = ""
    for i in a:
        if i.isnumeric()==False:
            vitri2=vitri2+1
            vitri1=vitri2
        else:
            vitri2=vitri2+1
            if a[vitri2].isnumeric()==False:
                tachso=a[vitri1:vitri2]
                chuoikq += tachso + ","
    return chuoikq[:-1]
        
def ham3(a):
    kihieu = ''
    for i in a :
        if (not i.isnumeric() and not i.isalpha()):
            kihieu = kihieu + i + " "
    return kihieu[:-1]    
#print(kihieu(a))

def main():
    chuoi=input("Nhập vào 1 chuối:")
    chonchayham=int(input("Nhập vào 1 số:"))
    while True:
        if chonchayham==1:
            print(ham1(chuoi))
        if chonchayham==2:
            print(ham2(chuoi))
        if chonchayham==3:
            print(ham3(chuoi))
        if chonchayham==0:
            print("Cảm ơn các bạn đã tin tưởng phần mêm của chúng tôi")
            break
        chonchayham=int(input("Nhập vào 1 số:"))

main()

# %% [markdown]
# ## Bài 2
#
# Các số nguyên dương: 3748, 58, 859, 32435465768 được gọi là các số đơn điệu do nếu quan sát các chữ số của các số này, ta thấy chúng luân phiên tăng giảm hoặc giảm tăng. Chẳng hạn:
#
# 3 < 7 > 4 < 8 và 3 > 2 < 4 > 3 < 5 > 4 < 6 > 5 < 7 > 6 < 8
#
# Số chỉ có một chữ số là số đơn điệu chiều dài 1.
#
# Nhiệm vụ:Viết chương trình xác định số chữ số đầu tiên lớn nhất tạo thành số đơn điệu của một số cho trước.
#
# Nhập vào: Từ bàn phím một số nguyên dương N có không quá 75 chữ số.
#
# In ra: Số nguyên K duy nhất chỉ số chữ số đầu tiên lớn nhất tạo thành số đơn điệu của số N.
#
# ##### Yêu cầu bắt buộc, viết hàm để kiểm tra số đơn điệu
#
# ![image.png](attachment:image.png)

# %%
a = "3748, 58, 859, 32435465768"

def kiemtrasodondieu(a):
    a = str(a)
    if len(a) == 1:
        return True
    if a[0] == a[1]:
        return False
    for i in range(len(a) - 2):
       # print(a[i],a[i+1],a[i+2])
        if not(int(a[i])>int(a[i+1])<int(a[i+2]) or int(a[i])<int(a[i+1])>int(a[i+2])):
           return False
    return True  
                            
N = input("Nhap vao N:")
                            
for i in range(1,len(N)+1):
    a = N[:i]
    # print(a,kiemtrasodondieu(a))                        
    
    if not kiemtrasodondieu(a):
        break
print(i-1)
# Out:
# Nhap vao N:37485885932435465768
# 6

# %%
# thay Dien
def kiemtradondieu(a):
    ## Kiểm tra coi a có phải là số đơn điệu hay không
    ## Nếu có trả về True, không có trả về False
    a = str(a)
    if len(a) == 1:
        return True
    if a[0] == a[1]:
        return False
    for i in range(len(a) - 2):
        # print(a[i],a[i+1],a[i+2])
        if not(int(a[i])>int(a[i+1])<int(a[i+2]) or int(a[i])<int(a[i+1])>int(a[i+2])):
            return False
    return True

N = input("Nhập vào N:")

for i in range(1,len(N)+1):
    a = N[:i]
    # print(a,kiemtradondieu(a))
    if not kiemtradondieu(a):
        break
print(i-1)

# %%
# thay Dien
N = input("Nhập vào N:")

if len(N) == 1:
    print(1)
elif len(N) == 2:
    if N[0] == N[1]:
        print(1)
    else:
        print(2)
else:
    for i in range(len(N) - 2):
        if not(int(N[i])>int(N[i+1])<int(N[i+2]) or int(N[i])<int(N[i+1])>int(N[i+2])):
            break    
    print(i+2)

# %%
## Tìm độ dài đoạn đơn điệu dài nhất trong N, không nhất thiết phải là đoạn đầu

N = input("Nhập vào N:")

if len(N) == 1:
    print(1)
elif len(N) == 2:
    if N[0] == N[1]:
        print(1)
    else:
        print(2)
else:
    dem = 0
    lonnhat = 0
    for i in range(len(N) - 2):
        if int(N[i])>int(N[i+1])<int(N[i+2]) or int(N[i])<int(N[i+1])>int(N[i+2]):
            dem += 1
        else:
            if dem > lonnhat:
                lonnhat = dem
                # print(lonnhat+2)
            dem = 0
    if dem > lonnhat:
        lonnhat = dem
        # print(lonnhat+2)
    print(lonnhat+2)

# %%
a = input('Enter a number:') # 3748 #3 - 7 = -4, 7 - 4 = 3 #7 - 4 = 3, 4 - 8 =-4
a1 = a

def check1(a1):
    count1 = 2
    if 0 <= int(a) <= 9:
        return 1
    elif 10 <= int(a) <= 99:
        if a[0] != a[1]:
            return 2
        else: 
            return 1
    else:
        for i in range(0,len(a)-2,1):
            if (int(a1[i]) - int(a1[i+1])) * (int(a1[i+1]) - int(a1[i+2])) < 0:
                count1 += 1
            else:
                return count1
        return count1

print(check1(a1))

# %%
day = input("Nhập vào dãy số: ")
def kiemtrasodondieu(day):
    a = 10
    n = 0
    k = 0
    for i in day:
        i = int(i)
        n = n+1
        if ((i > a and (n%2) == 0) or (i < a and (n%2) != 0)):
            k = k + 1
        else:
            return k
        a = i
print("k bằng",kiemtrasodondieu(day))

# %%
N=float(input("Nhập vào 1 số nguyên dương không quá 75 chữ số:"))
dem=0
while N!=int(N) or N<=0:
    N=float(input("Nhập vào 1 số nguyên dương không quá 75 chữ số:"))
a=N

while N!=0 :
    N=N//10
    dem=dem+1
    while dem>75:
        dem=0
        N=float(input("Nhập vào 1 số nguyên dương không quá 75 chữ số:"))
        a=N
        while N!=int(N) or N<=0:
            N=float(input("Nhập vào 1 số nguyên dương không quá 75 chữ số:"))
            a=N
            
def sodondieu(a,b):#xét hàm xét từng chữ số 1 
    if b==1:
        return 1
    if b==2 and str(a)[0]!=str(a)[1]:
        return 2
    if b==2 and str(a)[0]==str(a)[1]:
        return 1
    if b>=3:
        if str(a)[0]<str(a)[1]:
            dem=1
            so=2
            while dem<=b-2:
                if str(a)[dem+1]<str(a)[dem] and dem%2!=0:
                    dem=dem+1
                    so=so+1
                    print(so)
                elif str(a)[dem]<str(a)[dem+1] and dem%2==0:   
                    dem=dem+1
                    so=so+1
                    print(so)
                else:
                    return so
        elif str(a)[0]>str(a)[1]:
            dem=1
            so=2
            while dem<=b-2:
                if str(a)[dem+1]>str(a)[dem] and dem%2!=0:
                    dem=dem+1
                    so=so+1
                    print(so)
                elif str(a)[dem]>str(a)[dem+1] and dem%2==0:   
                    dem=dem+1
                    so=so+1
                    print(so)
                else:
                    return so
        elif str(a)[0]==str(a)[1]:
            return 1
print("Số nguyên K duy nhất chỉ số chữ số đầu tiên lớn nhất tạo thành số đơn điệu của số N")
print("K=",sodondieu(a,dem))

# %%
dem = 0

def hamdequy():
    global dem
    if dem < 10:
        print("hello")
        dem += 1
        hamdequy()
    
hamdequy()

# %%
dem = 3

def hama():
    global dem
    dem = 1

def hamb():
    global dem
    dem = 2
    #print(dem)

hama()
hamb()
print(dem)

# %%
# S = 1 + 2 + 3 + 4 + 5 + ... + n
# Dùng để quy để tính S
S=0
i=1
def tinh_tong(n):
    global S,i
    S+=i
    if i<n:
        i=i+1
        tinh_tong(n)

tinh_tong(5)
print(S)

# %%
S = 0
i = 1
def tinhS(n):
    global S,i
    if i<=n:
        S += i
        i += 1
        tinhS(n)
    else:
        print(S)
tinhS(5)

# %% [markdown]
# ![image.png](attachment:image.png)
